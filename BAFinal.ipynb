# %%
import pandas as pd 
alexa = pd.read_csv("Trips_2018.csv")

# %%
alexa.head()
# Out:
#    Unnamed: 0  tripduration                 starttime  \
# 0           0           970  2018-01-01 13:50:57.4340
# 1           1           723  2018-01-01 15:33:30.1820
# 2           2           496  2018-01-01 15:39:18.3370
# 3           3           306  2018-01-01 15:40:13.3720
# 4           4           306  2018-01-01 18:14:51.5680
#
#                    stoptime  start_station_id  start_station_latitude  \
# 0  2018-01-01 14:07:08.1860              72.0               40.767272
# 1  2018-01-01 15:45:33.3410              72.0               40.767272
# 2  2018-01-01 15:47:35.1720              72.0               40.767272
# 3  2018-01-01 15:45:20.1910              72.0               40.767272
# 4  2018-01-01 18:19:57.6420              72.0               40.767272
#
#    start_station_longitude  end_station_id  end_station_latitude  \
# 0               -73.993929           505.0             40.749013
# 1               -73.993929          3255.0             40.750585
# ...

# %%
alexa['starttime']
# Out:
# 0           2018-01-01 13:50:57.4340
# 1           2018-01-01 15:33:30.1820
# 2           2018-01-01 15:39:18.3370
# 3           2018-01-01 15:40:13.3720
# 4           2018-01-01 18:14:51.5680
#                       ...
# 17548334    2018-12-31 23:55:06.9910
# 17548335    2018-12-31 23:55:44.3070
# 17548336    2018-12-31 23:56:52.8500
# 17548337    2018-12-31 23:58:29.2120
# 17548338    2018-12-31 23:59:51.0850
# Name: starttime, Length: 17548339, dtype: object

# %%
alexa['starttime'] = pd.to_datetime(alexa['starttime'])
alexa['starttime'] = alexa['starttime'].dt.strftime('%Y/%m/%d %H:%M:%S')

# %%
#alexa['starttime']
alexa = alexa.set_index(alexa['starttime'])
alexa = alexa.sort_index()

# %%
training = alexa[:'2018/11/01']
testing = alexa['2018/11/01':]

# %%
training
# Out:
#                      Unnamed: 0  tripduration            starttime  \
# starttime
# 2018/01/01 00:01:50      115400           196  2018/01/01 00:01:50
# 2018/01/01 00:02:43      549193           207  2018/01/01 00:02:43
# 2018/01/01 00:03:15      192744           613  2018/01/01 00:03:15
# 2018/01/01 00:06:43      294006           375  2018/01/01 00:06:43
# 2018/01/01 00:06:56      248393           402  2018/01/01 00:06:56
# ...                         ...           ...                  ...
# 2018/10/31 23:59:31    15271416           647  2018/10/31 23:59:31
# 2018/10/31 23:59:38    15271417           314  2018/10/31 23:59:38
# 2018/10/31 23:59:46    15271418          1018  2018/10/31 23:59:46
# 2018/10/31 23:59:53    15271419           733  2018/10/31 23:59:53
# 2018/10/31 23:59:57    15271420           163  2018/10/31 23:59:57
#
#                                      stoptime  start_station_id  \
# starttime
# 2018/01/01 00:01:50  2018-01-01 00:05:07.4380             315.0
# ...

# %%
cortana = alexa[['start_station_longitude','start_station_latitude']].copy()

# %%
from sklearn.cluster import DBSCAN
cortana.head()
# Out:
#                      start_station_longitude  start_station_latitude
# starttime
# 2018/01/01 00:01:50               -74.006702               40.703554
# 2018/01/01 00:02:43               -74.005139               40.739974
# 2018/01/01 00:03:15               -74.002345               40.714948
# 2018/01/01 00:06:43               -73.991449               40.743954
# 2018/01/01 00:06:56               -73.985649               40.727791

# %%
cluster = DBSCAN(eps=5, min_samples=5).fit(cortana)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\adop\OneDrive - Danmarks Tekniske Universitet\BA Final\BAFinal.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/adop/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/BA%20Final/BAFinal.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> cluster = DBSCAN(eps=5, min_samples=5).fit(cortana)
#
# File c:\Users\adop\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# ...
